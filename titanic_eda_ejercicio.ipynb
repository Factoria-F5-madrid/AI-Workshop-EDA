# %% [markdown]
# # 🚢 Titanic EDA - Análisis Exploratorio de Datos
#
# **Objetivo**: ¿Qué factores determinaron quién sobrevivió al hundimiento del Titanic?
#
# En este notebook vas a:
# - Explorar y entender los datos del Titanic
# - Limpiar y preparar los datos
# - Crear visualizaciones para encontrar patrones
# - Responder preguntas sobre la supervivencia

# %% [markdown]
# ## 🛠️ Paso 0: Configuración Inicial
#
# Importa todas las librerías necesarias para el análisis.
#
# **Librerías a importar:**
# - `pandas` (como pd)
# - `numpy` (como np)
# - `matplotlib.pyplot` (como plt)
# - `seaborn` (como sns)
# - `kagglehub`
# - `os`
#
# **Configuración de gráficos:**
# - Establece el estilo de seaborn como "whitegrid"
# - Configura el tamaño de figura por defecto: (10, 6)

# %%
# Escribe aquí tu código para importar las librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import kagglehub
import os

# Configuración para que los gráficos se vean mejor
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ## 📥 Paso 1: Cargar los Datos
#
# Descarga el dataset del Titanic usando kagglehub y cárgalo en un DataFrame.
#
# **Tareas:**
# 1. Usa `kagglehub.dataset_download("yasserh/titanic-dataset")` para descargar
# 2. Guarda la ruta en una variable `path`
# 3. Carga el archivo 'Titanic-Dataset.csv' usando `pd.read_csv()`
# 4. Guarda el DataFrame en la variable `df`

# %%
# Escribe aquí tu código para descargar y cargar el dataset
import kagglehub
import os

# Descargar el dataset del Titanic desde Kaggle
path = kagglehub.dataset_download("yasserh/titanic-dataset")
print("Path to dataset files:", path)

# Cargar el archivo Titanic-Dataset.csv
df = pd.read_csv(os.path.join(path, 'Titanic-Dataset.csv'))
# Out:
# Using Colab cache for faster access to the 'titanic-dataset' dataset.
# Path to dataset files: /kaggle/input/titanic-dataset

# %% [markdown]
# ## 👀 Paso 2: Primera Exploración
#
# Examina las primeras filas del dataset para familiarizarte con los datos.

# %% [markdown]
# ### 2.1 Ver las primeras filas
#
# Usa `df.head()` para ver las primeras 5 filas del dataset.

# %%
# Escribe aquí tu código
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 2.2 Dimensiones del dataset
#
# Imprime cuántas filas (pasajeros) y columnas (características) tiene el dataset.
#
# **Pista:** Usa `df.shape`

# %%
# Escribe aquí tu código
df.shape
print(f"Filas: {df.shape[0]}, Columnas: {df.shape[1]}")
# Out:
# Filas: 891, Columnas: 12

# %% [markdown]
# ### 2.3 Información general
#
# Usa `df.info()` para ver:
# - Tipos de datos de cada columna
# - Cantidad de valores no nulos
# - Memoria que ocupa

# %%
# Escribe aquí tu código
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### 2.4 Columnas disponibles
#
# Muestra la lista de todas las columnas del dataset.
#
# **Pista:** Usa `df.columns.tolist()`

# %%
# Escribe aquí tu código
print(df.columns.tolist())
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %% [markdown]
# ## 📊 Paso 3: Estadística Descriptiva
#
# Obtén un resumen estadístico de las variables numéricas.

# %% [markdown]
# ### 3.1 Estadísticas de variables numéricas
#
# Usa `df.describe()` para ver:
# - Promedio (mean)
# - Desviación estándar (std)
# - Valores mínimo y máximo
# - Percentiles (25%, 50%, 75%)

# %%
# Escribe aquí tu código
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### 3.2 Estadísticas de variables categóricas
#
# Usa `df.describe(include='object')` para analizar las columnas de texto.

# %%
# Escribe aquí tu código
df.describe(include='object')
# Out:
#                        Name   Sex  Ticket Cabin Embarked
# count                   891   891     891   204      889
# unique                  891     2     681   147        3
# top     Dooley, Mr. Patrick  male  347082    G6        S
# freq                      1   577       7     4      644

# %% [markdown]
# ## 🧹 Paso 4: Limpieza de Datos

# %% [markdown]
# ### 4.1 Identificar valores faltantes
#
# Encuentra cuántos valores faltantes (NaN) hay en cada columna.
#
# **Pista:** Usa `df.isnull().sum()`

# %%
# Escribe aquí tu código
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### 4.2 Visualizar valores faltantes (porcentaje)
#
# Usando el paquete `missigno` para visualizar los datos faltante

# %% [markdown]
# Calcula el porcentaje de datos faltantes por columna.
#
# **Formula:** `(valores faltantes / total de filas) * 100`
#
# Muestra solo las columnas que tienen valores faltantes (porcentaje > 0).

# %%
# Escribe aquí tu código
missing_percent = (df.isnull().sum() / len(df)) * 100
print(missing_percent[missing_percent > 0])
# Out:
# Age         19.865320
# Cabin       77.104377
# Embarked     0.224467
# dtype: float64

# %% [markdown]
# ### 4.3 Eliminar columnas irrelevantes
#
# Elimina las siguientes columnas que no aportan al análisis:
# - PassengerId
# - Name
# - Ticket
# - Cabin
#
# **Pista:** Usa `df.drop([columnas], axis=1)`
#
# Después, muestra las primeras filas con `df.head()` para verificar.

# %%
# Escribe aquí tu código

# %% [markdown]
# ### 4.4 Imputar valores faltantes en Age
#
# Rellena los valores faltantes de la columna 'Age' con la **mediana**.
#
# **Pasos:**
# 1. Calcula la mediana de Age: `df['Age'].median()`
# 2. Rellena los valores faltantes: `df['Age'].fillna(mediana, inplace=True)`
# 3. Muestra las primeras 10 filas para verificar

# %%
# Escribe aquí tu código

# %% [markdown]
# ### 4.5 Imputar valores faltantes en Embarked
#
# Rellena los valores faltantes de 'Embarked' con la **moda** (valor más frecuente).
#
# **Pasos:**
# 1. Calcula la moda: `df['Embarked'].mode()[0]`
# 2. Rellena los valores faltantes
# 3. Muestra las primeras 10 filas

# %%
# Escribe aquí tu código

# %% [markdown]
# ### 4.6 Verificar que no queden valores faltantes
#
# Confirma que todas las columnas tienen 0 valores faltantes.
#
# **Pista:** Usa `df.isnull().sum()`

# %%
# Escribe aquí tu código

# %% [markdown]
# ## 🏷️ Paso 5: Renombrar Columnas
#
# Renombra las siguientes columnas para mayor claridad:
# - Pclass → Passenger_Class
# - SibSp → Siblings_Spouses
# - Parch → Parents_Children
#
# **Pista:** Usa `df.rename(columns={...})`
#
# Después muestra los nombres de las columnas y las primeras filas.

# %%
# Escribe aquí tu código

# %% [markdown]
# ## 📈 Paso 6: Análisis Univariado
#
# Analiza cada variable por separado para entender su distribución.

# %% [markdown]
# ### 6.1 Variable categórica: Survived
#
# **Tareas:**
# 1. Cuenta cuántos sobrevivieron (1) vs murieron (0): `df['Survived'].value_counts()`
# 2. Crea un gráfico de barras con colores rojo (no sobrevivió) y verde (sobrevivió)
#
# **Configuración del gráfico:**
# - kind='bar'
# - color=['red', 'green']
# - Título: 'Survival Count'
# - xlabel: 'Survived (0 = No, 1 = Yes)'
# - ylabel: 'Count'

# %%
# Escribe aquí tu código

# %% [markdown]
# ### 6.2 Variable categórica: Sex
#
# Crea un gráfico de barras mostrando la distribución de género.
#
# **Tareas:**
# 1. Cuenta los valores: `df['Sex'].value_counts()`
# 2. Crea gráfico con colores azul y rosa
# 3. Título: 'Gender Distribution'

# %%
# Escribe aquí tu código

# %% [markdown]
# ### 6.3 Variable numérica: Age
#
# Crea un **histograma** para ver la distribución de edades.
#
# **Configuración:**
# - kind='hist'
# - bins=30 (divide en 30 rangos)
# - edgecolor='black'
# - alpha=0.7
# - color='skyblue'
# - Título: 'Age Distribution'
# - xlabel: 'Age'
# - ylabel: 'Frequency'

# %%
# Escribe aquí tu código

# %% [markdown]
# ### 6.4 Variable numérica: Fare
#
# Crea un **boxplot** para detectar valores extremos en los precios.
#
# **Configuración:**
# - Usa `df.boxplot(column='Fare', patch_artist=True)`
# - Título: 'Fare Distribution'
# - ylabel: 'Fare'

# %%
# Escribe aquí tu código

# %% [markdown]
# ## 🔗 Paso 7: Análisis Bivariado
#
# Analiza la relación entre pares de variables.

# %% [markdown]
# ### 7.1 Survived vs Sex
#
# **Tareas:**
# 1. Crea una tabla cruzada con porcentajes por sexo:
#    - `pd.crosstab(df['Sex'], df['Survived'], normalize='index') * 100`
# 2. Crea un gráfico de barras agrupadas:
#    - `pd.crosstab(df['Sex'], df['Survived']).plot(kind='bar', color=['red', 'green'])`
#    - Añade título, labels y leyenda
#
# **Pregunta a responder:** ¿Quién tuvo más probabilidad de sobrevivir: hombres o mujeres?

# %%
# Escribe aquí tu código

# %% [markdown]
# ### 7.2 Survived vs Passenger_Class
#
# Analiza cómo la clase del pasajero afectó la supervivencia.
#
# **Tarea:**
# - Crea un gráfico de barras apiladas (stacked=True)
# - Usa colores rojo y verde
# - Título: 'Survival Rate by Passenger Class'
#
# **Pregunta:** ¿La primera clase tuvo ventaja?

# %%
# Escribe aquí tu código

# %% [markdown]
# ### 7.3 Age vs Survived
#
# Compara las distribuciones de edad entre sobrevivientes y no sobrevivientes.
#
# **Tareas:**
# 1. Crea dos histogramas superpuestos:
#    - Sobrevivientes (verde, alpha=0.5)
#    - No sobrevivientes (rojo, alpha=0.5)
# 2. bins=30, edgecolor='black'
# 3. Añade leyenda
#
# **Pregunta:** ¿Los niños tuvieron más probabilidad de sobrevivir?

# %%
# Escribe aquí tu código

# %% [markdown]
# ### 7.4 Fare vs Survived
#
# Compara los precios de tickets entre sobrevivientes y no sobrevivientes.
#
# **Tarea:**
# - Crea un boxplot comparativo: `df.boxplot(column='Fare', by='Survived')`
# - Usa `plt.suptitle('')` para quitar el título automático
# - Añade título y labels
#
# **Pregunta:** ¿Pagar más dinero aumentó las chances de sobrevivir?

# %%
# Escribe aquí tu código

# %% [markdown]
# ## 🎨 Paso 8: Análisis Multivariado
#
# Analiza múltiples variables simultáneamente.

# %% [markdown]
# ### 8.1 Matriz de correlación
#
# **Tareas:**
# 1. Selecciona solo las columnas numéricas:
#    - `numeric_df = df.select_dtypes(include=[np.number])`
# 2. Calcula la correlación:
#    - `correlation = numeric_df.corr()`
# 3. Imprime la matriz
#
# **¿Qué buscar?**
# - Valores cercanos a 1: correlación positiva fuerte
# - Valores cercanos a -1: correlación negativa fuerte
# - Valores cercanos a 0: sin correlación

# %%
# Escribe aquí tu código

# %% [markdown]
# ### 8.2 Heatmap de correlación
#
# Visualiza la matriz de correlación con un mapa de calor.
#
# **Configuración:**
# - `plt.figure(figsize=(10, 8))`
# - `sns.heatmap(correlation, annot=True, cmap='coolwarm', center=0, linewidths=1, fmt='.2f', square=True)`
# - Título: 'Correlation Matrix - Titanic Dataset'
# - Usa `plt.tight_layout()`
#
# **Interpretación:**
# - Rojo/naranja = correlación positiva
# - Azul = correlación negativa
# - Blanco = sin correlación

# %%
# Escribe aquí tu código

# %% [markdown]
# ### 8.3 Pairplot
#
# Crea una matriz de gráficos mostrando relaciones entre todas las variables numéricas.
#
# **Configuración:**
# - `sns.pairplot(numeric_df, hue='Survived', palette={0: 'red', 1: 'green'}, diag_kind='hist', plot_kws={'alpha': 0.6})`
# - Añade título con `plt.suptitle('Pairplot of Numeric Variables by Survival', y=1.02)`
#
# **Nota:** Este gráfico puede tardar un poco porque genera muchas visualizaciones.

# %%
# Escribe aquí tu código

# %% [markdown]
# ## 📊 Paso 9: Feature Engineering Básico
#
# Crea nuevas variables a partir de las existentes.

# %% [markdown]
# ### 9.1 Crear variable Family_Size
#
# **Tareas:**
# 1. Crea la columna: `df['Family_Size'] = df['Siblings_Spouses'] + df['Parents_Children'] + 1`
# 2. Muestra las columnas relacionadas: `df[['Siblings_Spouses', 'Parents_Children', 'Family_Size']].head(10)`
# 3. Crea un histograma de Family_Size con:
#    - bins=10
#    - color='orange'
#    - edgecolor='black'

# %%
# Escribe aquí tu código

# %% [markdown]
# ### 9.2 Crear variable Is_Alone
#
# **Tareas:**
# 1. Crea variable binaria: `df['Is_Alone'] = (df['Family_Size'] == 1).astype(int)`
# 2. Muestra las columnas: `df[['Family_Size', 'Is_Alone']].head(10)`
# 3. Analiza supervivencia con crosstab y gráfico de barras
#
# **Pregunta:** ¿Viajar solo fue ventaja o desventaja?

# %%
# Escribe aquí tu código

# %% [markdown]
# ### 9.3 Crear variable Age_Group
#
# **Tareas:**
# 1. Categoriza las edades:
# ```python
# df['Age_Group'] = pd.cut(df['Age'],
#                          bins=[0, 12, 18, 35, 60, 100],
#                          labels=['Child', 'Teenager', 'Young Adult', 'Adult', 'Senior'])
# ```
# 2. Muestra: `df[['Age', 'Age_Group']].head(15)`
# 3. Crea gráfico de barras de supervivencia por grupo de edad
#
# **Pregunta:** ¿Los niños tuvieron prioridad ("mujeres y niños primero")?

# %%
# Escribe aquí tu código

# %% [markdown]
# ## 📝 Paso 10: Conclusiones
#
# Escribe código para responder estas preguntas clave:

# %% [markdown]
# ### 10.1 Tasa de supervivencia general
#
# Calcula qué porcentaje del total de pasajeros sobrevivió.
#
# **Formula:** `(df['Survived'].sum() / len(df)) * 100`

# %%
# Escribe aquí tu código

# %% [markdown]
# ### 10.2 Supervivencia por sexo
#
# Calcula el porcentaje de supervivencia para hombres y mujeres por separado.
#
# **Pista:** `df.groupby('Sex')['Survived'].mean() * 100`

# %%
# Escribe aquí tu código

# %% [markdown]
# ### 10.3 Supervivencia por clase
#
# Calcula el porcentaje de supervivencia para cada clase (1, 2, 3).
#
# **Pista:** `df.groupby('Passenger_Class')['Survived'].mean() * 100`

# %%
# Escribe aquí tu código

# %% [markdown]
# ### 10.4 Edad promedio por supervivencia
#
# Compara la edad promedio de:
# - Los que sobrevivieron
# - Los que no sobrevivieron
#
# **Pista:** `df.groupby('Survived')['Age'].mean()`

# %%
# Escribe aquí tu código

# %% [markdown]
# ## 🎉 ¡Felicidades!
#
# Has completado tu primer Análisis Exploratorio de Datos.
#
# ### 📋 Resumen de lo que aprendiste:
#
# 1. ✅ Cargar y explorar datos
# 2. ✅ Identificar y limpiar valores faltantes
# 3. ✅ Crear estadísticas descriptivas
# 4. ✅ Visualizar datos con múltiples tipos de gráficos
# 5. ✅ Analizar relaciones entre variables
# 6. ✅ Crear nuevas variables (Feature Engineering)
# 7. ✅ Extraer conclusiones de los datos
#
# ### 🤔 Reflexiones finales:
#
# **Escribe tus conclusiones aquí:**
# - ¿Qué factores fueron más importantes para sobrevivir?
# - ¿Qué te sorprendió más del análisis?
# - ¿Qué otras preguntas te gustaría investigar?
#
# ### 🚀 Próximos pasos:
#
# 1. Crear un modelo de Machine Learning para predecir supervivencia
# 2. Probar con otros datasets de Kaggle
# 3. Crear visualizaciones más avanzadas con Plotly
# 4. Compartir tu análisis en un blog o GitHub

# %% [markdown]
# ---
#
# **Dataset:** [Titanic Dataset by Yasserh](https://www.kaggle.com/datasets/yasserh/titanic-dataset)
